# %%
# Data import and cleaning.

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

# Just a maybe-useful but messy function for seeing what's going on in the data table:
def describe_data(data):
    for col in data.columns:
        valc=data[col].value_counts()
        print('--------------')
        print('* ',col,len(valc),'values.')
        if len(valc)<10:
            print(valc)
        print(data[col].isnull().sum(),'NaNs')

# Performs one-hot encoding on all non-numerical variables and also drops rows containing missing data:
def one_hot(data):
    bad_columns=[]
    for col in data.columns:
        if data[col].dtype=='object':
            bad_columns.append(col)
    return pd.get_dummies(data.dropna(),columns=bad_columns,drop_first=False)
    
def downsample(data,var_to_balance):
    vc=data[var_to_balance].value_counts()
    imin=vc.idxmin()
    result=data[data[var_to_balance]==imin]
    for i in vc.index:
        if i!=imin:
            result=pd.concat([result,data[data[var_to_balance]==i].sample(vc[imin])])
    return result
    
raw_data=pd.read_csv("anemia_neater.csv")
raw_data['mothers_education']=raw_data['mothers_education'].map({'No education':0,'Primary':1,'Secondary':2,'Higher':3})
raw_data['mothers_wealth_index']=raw_data['mothers_wealth_index'].map({'Poorest':0,'Poorer':1,'Middle':2,'Richer':3,'Richest':4})
#describe_data(raw_data)

# Replace mother's age group with the lowest boundary of respective age group (a useful numerical value):
clean_data=raw_data.assign(mothers_age_group = raw_data['mothers_age_group'].str[:2].astype(int),
                          child_tested = 1 - raw_data['childs_hemoglobin'].isna())

# Binarise the anemia dignosis columns
clean_data.replace({'Not anemic':0,'Mild':1,'Moderate':1,'Severe':1},inplace=True)

# A few "Don't know" values in the table; interpret as missing data:
clean_data.replace("Don't know",np.NaN,inplace=True)
# Yes/No to numbers; less one-hotting and clearer table:
clean_data.replace('Yes',1,inplace=True)
clean_data.replace('No',0,inplace=True)
#describe_data(clean_data)

# Just tables for subsequent analyses:
#testing_data=downsample(one_hot(clean_data.drop(columns=['mothers_anemia','mothers_hemoglobin','childs_hemoglobin','childs_anemia'])),'child_tested')
testing_data=one_hot(clean_data.drop(columns=['mothers_anemia','mothers_hemoglobin','childs_hemoglobin','childs_anemia']))
anemia_data=downsample(one_hot(clean_data.drop(columns=['mothers_hemoglobin','childs_hemoglobin','child_tested'])),'childs_anemia')
regression_data=one_hot(clean_data.drop(columns=['mothers_anemia','mothers_hemoglobin','childs_anemia','child_tested']))

print(anemia_data.shape)

corrs=anemia_data.corr()
corrs.style.background_gradient(cmap='coolwarm')
# Out:
# (5940, 17)
# <style type="text/css">
# #T_e0904_row0_col0, #T_e0904_row1_col1, #T_e0904_row2_col2, #T_e0904_row3_col3, #T_e0904_row4_col4, #T_e0904_row5_col5, #T_e0904_row6_col6, #T_e0904_row7_col7, #T_e0904_row8_col8, #T_e0904_row9_col9, #T_e0904_row10_col10, #T_e0904_row11_col11, #T_e0904_row12_col12, #T_e0904_row13_col13, #T_e0904_row14_col14, #T_e0904_row15_col15, #T_e0904_row16_col16 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_e0904_row0_col1, #T_e0904_row5_col2, #T_e0904_row8_col9 {
#   background-color: #92b4fe;
#   color: #000000;
# }
# #T_e0904_row0_col2, #T_e0904_row4_col0, #T_e0904_row13_col2 {
#   background-color: #bbd1f8;
#   color: #000000;
# }
# #T_e0904_row0_col3, #T_e0904_row2_col5, #T_e0904_row2_col6, #T_e0904_row2_col8, #T_e0904_row2_col9, #T_e0904_row3_col0, #T_e0904_row8_col7, #T_e0904_row11_col1, #T_e0904_row11_col2, #T_e0904_row11_col4, #T_e0904_row11_col10, #T_e0904_row11_col12, #T_e0904_row12_col11, #T_e0904_row13_col14, #T_e0904_row14_col13, #T_e0904_row15_col16, #T_e0904_row16_col15 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_e0904_row0_col4, #T_e0904_row4_col15 {
#   background-color: #d1dae9;
#   color: #000000;
# }
# #T_e0904_row0_col5 {
#   background-color: #5470de;
#   color: #f1f1f1;
# }
# #T_e0904_row0_col6, #T_e0904_row5_col10, #T_e0904_row7_col0, #T_e0904_row13_col6 {
#   background-color: #5572df;
#   color: #f1f1f1;
# }
# #T_e0904_row0_col7, #T_e0904_row12_col5 {
#   background-color: #4055c8;
#   color: #f1f1f1;
# }
# #T_e0904_row0_col8, #T_e0904_row0_col9, #T_e0904_row5_col6, #T_e0904_row7_col3, #T_e0904_row7_col8 {
#   background-color: #5b7ae5;
#   color: #f1f1f1;
# }
# #T_e0904_row0_col10, #T_e0904_row15_col6, #T_e0904_row16_col9 {
#   background-color: #6485ec;
#   color: #f1f1f1;
# }
# #T_e0904_row0_col11, #T_e0904_row2_col14, #T_e0904_row3_col12 {
#   background-color: #d5dbe5;
#   color: #000000;
# }
# #T_e0904_row0_col12, #T_e0904_row2_col13, #T_e0904_row3_col11 {
#   background-color: #e4d9d2;
#   color: #000000;
# }
# #T_e0904_row0_col13, #T_e0904_row2_col15 {
#   background-color: #d6dce4;
#   color: #000000;
# }
# #T_e0904_row0_col14, #T_e0904_row2_col4, #T_e0904_row2_col16 {
#   background-color: #e3d9d3;
#   color: #000000;
# }
# #T_e0904_row0_col15, #T_e0904_row3_col14 {
#   background-color: #dfdbd9;
#   color: #000000;
# }
# #T_e0904_row0_col16, #T_e0904_row3_col13 {
#   background-color: #dadce0;
#   color: #000000;
# }
# #T_e0904_row1_col0, #T_e0904_row8_col3, #T_e0904_row10_col8 {
#   background-color: #516ddb;
#   color: #f1f1f1;
# }
# #T_e0904_row1_col2 {
#   background-color: #f29274;
#   color: #f1f1f1;
# }
# #T_e0904_row1_col3, #T_e0904_row12_col9 {
#   background-color: #4c66d6;
#   color: #f1f1f1;
# }
# #T_e0904_row1_col4 {
#   background-color: #efcfbf;
#   color: #000000;
# }
# #T_e0904_row1_col5, #T_e0904_row5_col7, #T_e0904_row12_col6 {
#   background-color: #4358cb;
#   color: #f1f1f1;
# }
# #T_e0904_row1_col6 {
#   background-color: #3c4ec2;
#   color: #f1f1f1;
# }
# #T_e0904_row1_col7 {
#   background-color: #3e51c5;
#   color: #f1f1f1;
# }
# #T_e0904_row1_col8, #T_e0904_row4_col7, #T_e0904_row6_col7 {
#   background-color: #4257c9;
#   color: #f1f1f1;
# }
# #T_e0904_row1_col9, #T_e0904_row9_col7, #T_e0904_row12_col7, #T_e0904_row13_col7, #T_e0904_row15_col7 {
#   background-color: #3f53c6;
#   color: #f1f1f1;
# }
# #T_e0904_row1_col10 {
#   background-color: #9dbdff;
#   color: #000000;
# }
# #T_e0904_row1_col11 {
#   background-color: #a1c0ff;
#   color: #000000;
# }
# #T_e0904_row1_col12 {
#   background-color: #f7af91;
#   color: #000000;
# }
# #T_e0904_row1_col13 {
#   background-color: #e7d7ce;
#   color: #000000;
# }
# #T_e0904_row1_col14, #T_e0904_row10_col2 {
#   background-color: #d2dbe8;
#   color: #000000;
# }
# #T_e0904_row1_col15, #T_e0904_row9_col12 {
#   background-color: #ccd9ed;
#   color: #000000;
# }
# #T_e0904_row1_col16, #T_e0904_row9_col11 {
#   background-color: #ebd3c6;
#   color: #000000;
# }
# #T_e0904_row2_col0, #T_e0904_row7_col9 {
#   background-color: #6a8bef;
#   color: #f1f1f1;
# }
# #T_e0904_row2_col1 {
#   background-color: #f49a7b;
#   color: #000000;
# }
# #T_e0904_row2_col3, #T_e0904_row4_col9, #T_e0904_row10_col6 {
#   background-color: #4b64d5;
#   color: #f1f1f1;
# }
# #T_e0904_row2_col7 {
#   background-color: #3d50c3;
#   color: #f1f1f1;
# }
# #T_e0904_row2_col10, #T_e0904_row11_col9 {
#   background-color: #8fb1fe;
#   color: #000000;
# }
# #T_e0904_row2_col11, #T_e0904_row9_col5, #T_e0904_row9_col8 {
#   background-color: #89acfd;
#   color: #000000;
# }
# #T_e0904_row2_col12 {
#   background-color: #f39577;
#   color: #000000;
# }
# #T_e0904_row3_col1 {
#   background-color: #8db0fe;
#   color: #000000;
# }
# #T_e0904_row3_col2 {
#   background-color: #a3c2fe;
#   color: #000000;
# }
# #T_e0904_row3_col4, #T_e0904_row6_col3, #T_e0904_row9_col1, #T_e0904_row14_col8 {
#   background-color: #6c8ff1;
#   color: #f1f1f1;
# }
# #T_e0904_row3_col5, #T_e0904_row5_col4, #T_e0904_row8_col5, #T_e0904_row14_col0, #T_e0904_row14_col6 {
#   background-color: #6687ed;
#   color: #f1f1f1;
# }
# #T_e0904_row3_col6, #T_e0904_row3_col9, #T_e0904_row6_col8 {
#   background-color: #7295f4;
#   color: #f1f1f1;
# }
# #T_e0904_row3_col7, #T_e0904_row9_col0, #T_e0904_row11_col0, #T_e0904_row12_col3 {
#   background-color: #465ecf;
#   color: #f1f1f1;
# }
# #T_e0904_row3_col8, #T_e0904_row14_col3, #T_e0904_row14_col5 {
#   background-color: #5e7de7;
#   color: #f1f1f1;
# }
# #T_e0904_row3_col10, #T_e0904_row14_col10 {
#   background-color: #536edd;
#   color: #f1f1f1;
# }
# #T_e0904_row3_col15, #T_e0904_row11_col14, #T_e0904_row12_col13, #T_e0904_row13_col12, #T_e0904_row14_col11 {
#   background-color: #e1dad6;
#   color: #000000;
# }
# #T_e0904_row3_col16, #T_e0904_row11_col13, #T_e0904_row12_col14, #T_e0904_row13_col11, #T_e0904_row14_col12 {
#   background-color: #d8dce2;
#   color: #000000;
# }
# #T_e0904_row4_col1 {
#   background-color: #f5c4ac;
#   color: #000000;
# }
# #T_e0904_row4_col2 {
#   background-color: #f3c7b1;
#   color: #000000;
# }
# #T_e0904_row4_col3 {
#   background-color: #4a63d3;
#   color: #f1f1f1;
# }
# #T_e0904_row4_col5, #T_e0904_row6_col10, #T_e0904_row8_col10, #T_e0904_row13_col0 {
#   background-color: #485fd1;
#   color: #f1f1f1;
# }
# #T_e0904_row4_col6, #T_e0904_row11_col7, #T_e0904_row14_col7 {
#   background-color: #445acc;
#   color: #f1f1f1;
# }
# #T_e0904_row4_col8, #T_e0904_row10_col7 {
#   background-color: #4961d2;
#   color: #f1f1f1;
# }
# #T_e0904_row4_col10 {
#   background-color: #8caffe;
#   color: #000000;
# }
# #T_e0904_row4_col11 {
#   background-color: #bad0f8;
#   color: #000000;
# }
# #T_e0904_row4_col12 {
#   background-color: #f4c6af;
#   color: #000000;
# }
# #T_e0904_row4_col13, #T_e0904_row5_col14, #T_e0904_row5_col15, #T_e0904_row7_col14, #T_e0904_row7_col16, #T_e0904_row9_col13, #T_e0904_row10_col16, #T_e0904_row13_col16, #T_e0904_row14_col15, #T_e0904_row15_col14, #T_e0904_row16_col13 {
#   background-color: #dedcdb;
#   color: #000000;
# }
# #T_e0904_row4_col14, #T_e0904_row5_col13, #T_e0904_row5_col16, #T_e0904_row7_col13, #T_e0904_row7_col15, #T_e0904_row9_col14, #T_e0904_row10_col15, #T_e0904_row13_col15, #T_e0904_row14_col16, #T_e0904_row15_col13, #T_e0904_row16_col14 {
#   background-color: #dbdcde;
#   color: #000000;
# }
# #T_e0904_row4_col16 {
#   background-color: #e8d6cc;
#   color: #000000;
# }
# #T_e0904_row5_col0, #T_e0904_row6_col0, #T_e0904_row8_col0 {
#   background-color: #4f69d9;
#   color: #f1f1f1;
# }
# #T_e0904_row5_col1 {
#   background-color: #80a3fa;
#   color: #f1f1f1;
# }
# #T_e0904_row5_col3, #T_e0904_row7_col10, #T_e0904_row10_col9, #T_e0904_row13_col10, #T_e0904_row15_col3 {
#   background-color: #6180e9;
#   color: #f1f1f1;
# }
# #T_e0904_row5_col8 {
#   background-color: #6e90f2;
#   color: #f1f1f1;
# }
# #T_e0904_row5_col9 {
#   background-color: #98b9ff;
#   color: #000000;
# }
# #T_e0904_row5_col11, #T_e0904_row6_col11 {
#   background-color: #e9d5cb;
#   color: #000000;
# }
# #T_e0904_row5_col12, #T_e0904_row6_col12 {
#   background-color: #cfdaea;
#   color: #000000;
# }
# #T_e0904_row6_col1, #T_e0904_row7_col4, #T_e0904_row11_col5, #T_e0904_row15_col1 {
#   background-color: #799cf8;
#   color: #f1f1f1;
# }
# #T_e0904_row6_col2 {
#   background-color: #90b2fe;
#   color: #000000;
# }
# #T_e0904_row6_col4, #T_e0904_row8_col4, #T_e0904_row15_col4, #T_e0904_row15_col5 {
#   background-color: #5f7fe8;
#   color: #f1f1f1;
# }
# #T_e0904_row6_col5, #T_e0904_row13_col8 {
#   background-color: #5a78e4

# %%
# Classifiers.

from sklearn.model_selection import cross_val_score
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier, VotingClassifier, AdaBoostClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import make_pipeline

# Returns a confusion matrix from given predicted probabilities vs actual labels and a threshold value.
def calculate_confusion(y_pred,y_test,threshold):
    df=pd.DataFrame({'p':y_pred, 'y':y_test.reset_index(drop=True)})
    df['predicted'] = (df['p']>=threshold)
    tots=len(df['predicted'])
    fp=(df['predicted']>df['y']).sum()
    fn=(df['predicted']<df['y']).sum()
    tp=df['predicted'].sum() - fp;
    tn = tots - fp - fn - tp;
    return ([[tp, fn], [fp, tn]])

# Just F-score from a model and test data:
def calculate_F (model,X_test,y_test):
    predictions=model.predict(X_test)
    TP=((predictions==1) & (y_test==1)).sum()
    FP=(predictions>y_test).sum()
    FN=(predictions<y_test).sum()
    return 2*TP/(2*TP+FP+FN)

# Calculates an approximate ROC curve for given classifier model, and returns its AUC. 
# If drawPicture=True (default) then also draws the curve, otherwise simply does the calculations for AUC.
# If showCutoff in given then draws a cross on the curve at that point.
# plt.show() is not called, so subsequent drawings go to the same picture (useful for comparing models).
def analyse_ROC(model,X_test,y_test,title='',steps=100,drawPicture=True,showCutoff=None):
    probabilities=pd.DataFrame(model.predict_proba(X_test))
    p=0
    dp=1/steps
    tpr_array=[]
    fpr_array=[]
    while p<=1:
        confusion=calculate_confusion(probabilities[1],y_test,p)
        tpr_array.append(confusion[0][0]/sum(confusion[0]))
        fpr_array.append(confusion[1][0]/sum(confusion[1]))
        p+=dp
    tpr_array.append(0)
    fpr_array.append(0)
    tpr_array=np.array(tpr_array)
    fpr_array=np.array(fpr_array)
    AUC=0
    for i in range(1,len(tpr_array)):
        AUC += (tpr_array[i-1]+tpr_array[i])/2 * (fpr_array[i-1]-fpr_array[i])
    
    if drawPicture:
        plt.plot(fpr_array,tpr_array,
                 label="{title}: AUC = {AUC:.3f}".format(title=title,AUC=AUC))   # ,F=calculate_F(model,X_test,y_test)
        if not (showCutoff is None):
            confusion=calculate_confusion(probabilities[1],y_test,showCutoff)
            plt.plot(confusion[1][0]/sum(confusion[1]),confusion[0][0]/sum(confusion[0]),'r+',markersize=8)
        plt.xlabel('FPR')
        plt.ylabel('TPR')
    return AUC

def compare_models(models,data,dep_column):
    X_train,X_test,y_train,y_test = train_test_split(anemia_data.drop(columns=dep_column),
                                                 anemia_data[dep_column],
                                                 test_size=0.25)
    print('Cross validated F-scores:')
    for pair in models:
        mud=pair[1].fit(X_train,y_train)
        analyse_ROC(mud,X_test,y_test,title=pair[0],steps=4000)
        F1=cross_val_score(pair[1],X_train,y_train,scoring='f1').mean()
        print("%s: F = %.3f" % (pair[0],F1))
    mud=VotingClassifier(models,voting='soft').fit(X_train,y_train)
    analyse_ROC(mud,X_test,y_test,title='Voted between others',steps=4000)
    plt.legend()
    plt.show()
    

#X_train,X_test,y_train,y_test = train_test_split(testing_data.drop(columns="child_tested"),
#                                                 testing_data["child_tested"],
#                                                 test_size=0.3)

X_train,X_test,y_train,y_test = train_test_split(anemia_data.drop(columns="childs_anemia"),
                                                 anemia_data["childs_anemia"],
                                                 test_size=0.3)

logReg=LogisticRegression(max_iter=1000) # make_pipeline(StandardScaler(),LogisticRegression())
quadSVM=SVC(kernel='poly',degree=2,gamma='scale',probability=True)

classifiers = [
    ('random forest',RandomForestClassifier(n_estimators=100,max_samples=0.03,max_depth=None,n_jobs=6)),
    ('gradient boosted',GradientBoostingClassifier()),
    ('logistic reg',logReg), # LogisticRegression(max_iter=1000)),
    ('quadratic SVM',quadSVM),
    #('AdaBoost',AdaBoostClassifier(n_estimators=100)) # horrible
]

print("* Without mothers' blood data: *")
compare_models(classifiers,anemia_data.drop(columns=['mothers_anemia']),'childs_anemia')
#print("With mother' blood data")
#compare_models(classifiers,anemia_data,'childs_anemia')
# Out:
# * Without mothers' blood data: *
# Cross validated F-scores:
# random forest: F = 0.593
# gradient boosted: F = 0.604
# logistic reg: F = 0.595
# quadratic SVM: F = 0.620

# %%
# Model goodness table

def calculate_scores(models,scores,X_train,y_train):
    extended_models=models + [('voted',VotingClassifier(models,voting='soft'))]
    result=pd.DataFrame()
    for score in scores:
        ser=[]
        for model in extended_models:
            s=cross_val_score(model[1],X_train,y_train,scoring=score).mean()
            ser.append(s)
        result[score]=ser
    result.index=[pair[0] for pair in extended_models]
    return result

calculate_scores(classifiers,['accuracy','f1','roc_auc','recall'],X_train.drop(columns=['mothers_anemia']),y_train)
# Out:
#                   accuracy    f1  roc_auc  recall
# random forest        0.586 0.581    0.618   0.567
# gradient boosted     0.586 0.581    0.621   0.574
# logistic reg         0.589 0.589    0.627   0.588
# quadratic SVM        0.583 0.613    0.622   0.661
# voted                0.592 0.594    0.632   0.606

# %%
untested_data=testing_data[testing_data['child_tested']==0].drop(columns='child_tested')
untested_data.head()

model=logReg.fit(X_train.drop(columns='mothers_anemia'),y_train)
#model=quadSVM.fit(X_train.drop(columns='mothers_anemia'),y_train)
predictions2=pd.DataFrame(model.predict_proba(untested_data))
predictions2.columns=['Not','Anemic']
ax=predictions2['Anemic'].hist(bins=20,grid=False)
ax.set_xlabel('Probability to be anemic')
ax.set_ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %%
# Regressions

from sklearn.linear_model import LinearRegression,Lasso,Ridge

# Just sum of squared deviations from mean for given array y
def SumSqr(y):
    y_mean=y.mean()
    return ((y-y_mean)**2).sum()

# Returns R-squared for given model - how much of the ebserved variance of y_obs it explains
def R2Model(model,X_obs,y_obs):
    return 1 - SumSqr(y_obs-model.predict(X_obs))/SumSqr(y_obs)

# Draws observed vs predicted scatterplot for given model; returns R2 as above
def ShowModel(model,X_obs,y_obs,obs_lab='Observed',pred_lab='Predicted'):
    y_pred=model.predict(X_obs)
    plt.plot(y_obs,y_pred,'ro',markersize=2)
    plt.xlabel(obs_lab)
    plt.ylabel(pred_lab)
    plt.show()
    return 1 - SumSqr(y_obs-y_pred)/SumSqr(y_obs)    

X_train, X_test, y_train, y_test = train_test_split(regression_data.drop(columns='childs_hemoglobin'),
                                                    regression_data['childs_hemoglobin'],test_size=0.3)

# Make some regression model and draw the resulting observed vs predicted relation:
model=Lasso(alpha=0.1).fit(X_train,y_train)
#model=LinearRegression().fit(X_train,y_train)

# Print out the model's corfs:
for i in range(0,len(model.coef_)):
    print('%s: %0.4f' % (model.feature_names_in_[i],model.coef_[i]))
    
# Show observed vs predicted graph and print R2:
print('R2 = %0.3f' % ShowModel(model,X_test,y_test,obs_lab="Observed hemoglobin",pred_lab="Predicted hemoglobin"))
# Out:
# mothers_age_group: 0.0842
# mothers_births_5y: -0.3193
# mothers_age_at_1st_birth: 0.1476
# mothers_residence_Urban: 0.8333
# mothers_education_No education: -1.1615
# mothers_education_Primary: -0.6023
# mothers_education_Secondary: -0.0000
# mothers_wealth_index_Poorer: -2.0917
# mothers_wealth_index_Poorest: -4.2365
# mothers_wealth_index_Richer: 0.0000
# mothers_wealth_index_Richest: 3.4961
# mosquito_net_Yes: -0.0000
# mother_smokes_Yes: 0.0000
# mothers_marital_Married: 0.0000
# mothers_partner_Staying elsewhere: 0.0000
# fever_last_2_weeks_Yes: -3.6668
# iron_pills_Yes: -0.0000
# R2 = 0.073

# %%
X_train,X_test,y_train,y_test = train_test_split(anemia_data.drop(columns="childs_anemia"),
                                                 anemia_data["childs_anemia"],
                                                 test_size=0.3)
from sklearn.linear_model import LogisticRegression
import pandas as pd

# Assuming you have already defined and trained your model
model = LogisticRegression()
model.fit(X_train, y_train)  
feature_names = X_train.columns
coefficients = model.coef_[0]  # Assuming binary classification; adjust for multiclass if needed
intercept = model.intercept_[0]  # Assuming binary classification; adjust for multiclass if needed

# Create a DataFrame to display feature names and coefficients
coefficients_df = pd.DataFrame({'Feature': feature_names, 'Coefficient': coefficients})

# Display the intercept
print("Intercept:", intercept)

# Display the coefficients
print(coefficients_df)

import matplotlib.pyplot as plt
plt.figure(figsize=(10, 6))
plt.barh(coefficients_df['Feature'], coefficients_df['Coefficient'])
plt.xlabel('Coefficient Value')
plt.title('Logistic Regression Coefficients')
plt.show()
plt.savefig('logistic_regression_coefficients.png', bbox_inches='tight')  # Added 'bbox_inches' to include the entire figure
# Out:
# C:\Users\subhashini\AppData\Local\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# Intercept: 0.22979532337540154
#                                 Feature  Coefficient
# 0                     mothers_age_group    -0.009094
# 1                     mothers_education    -0.169015
# 2                  mothers_wealth_index    -0.162867
# 3                     mothers_births_5y    -0.003440
# 4              mothers_age_at_1st_birth    -0.004227
# 5                        mothers_anemia     0.544477
# 6                          mosquito_net     0.047797
# 7                         mother_smokes    -0.037103
# 8                    fever_last_2_weeks     0.466312
# 9                            iron_pills     0.008854
# 10              mothers_residence_Rural     0.109112
# 11              mothers_residence_Urban     0.112507
# 12  mothers_marital_Living with partner     0.243309
# 13              mothers_marital_Married    -0.021690
# 14      mothers_partner_Living with her     0.145636
# 15    mothers_partner_Staying elsewhere     0.075983

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

# Assuming you have already defined and trained your model
model = LogisticRegression()
model.fit(X_train, y_train)

# Make predictions on the test set
predictions = model.predict(X_test)

# Generate the confusion matrix with normalization
conf_matrix = confusion_matrix(y_test, predictions, normalize='all')

# Create a heatmap for the normalized confusion matrix with a color bar
plt.figure(figsize=(8, 6))
heatmap = sns.heatmap(conf_matrix, annot=True, fmt='.2%', cmap='Blues', cbar=True,
                     xticklabels=['Not Anemic', 'Anemic'],
                     yticklabels=['Not Anemic', 'Anemic'])
plt.title('Normalized Confusion Matrix')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')

# Adjust color bar label format
heatmap.figure.axes[-1].set_ylabel('Proportion', size=12)

plt.show()
# Out:
# C:\Users\subhashini\AppData\Local\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
