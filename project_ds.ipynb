# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("children_anemia.csv")
data.shape
# Out:
# (33924, 17)

# %%
data.head()
# Out:
#   Age in 5-year groups Type of place of residence Highest educational level  \
# 0                40-44                      Urban                    Higher
# 1                35-39                      Urban                    Higher
# 2                25-29                      Urban                    Higher
# 3                25-29                      Urban                 Secondary
# 4                20-24                      Urban                 Secondary
#
#   Wealth index combined  Births in last five years  \
# 0               Richest                          1
# 1               Richest                          1
# 2               Richest                          1
# 3               Richest                          1
# 4               Richest                          1
#
#    Age of respondent at 1st birth  \
# 0                              22
# 1                              28
# 2                              26
# 3                              25
# ...

# %%
data["Hemoglobin level adjusted for altitude and smoking (g/dl - 1 decimal)"].value_counts()
# Out:
# Hemoglobin level adjusted for altitude and smoking (g/dl - 1 decimal)
# 113.0    400
# 116.0    375
# 112.0    372
# 108.0    367
# 111.0    361
#         ...
# 44.0       1
# 27.0       1
# 166.0      1
# 53.0       1
# 162.0      1
# Name: count, Length: 123, dtype: int64
